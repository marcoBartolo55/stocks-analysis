# %% [markdown]
# # S&P 500 Companies with Financial Information
#
# **Variables financieras:**
# *   Price
# *   Price to Earnings (PE)
# *   Dividend Yield
# *   Earnings Per Share (EPS)
# *   52 Week High
# *   52 Week Low
# *   Market Cap
# *   EMBITDA
# *   Price to Sales (PS)
# *   Price to Book (PB)
#
# **Variables descriptivas:**
# *   Symbol
# *   Name
# *   Sector

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
from sklearn.preprocessing import RobustScaler
import plotly.express as px

# %% [markdown]
# **Carga de datos**

# %%
df = pd.read_csv('/content/financials.csv')
df.head()
# Out:
#   Symbol                 Name                  Sector   Price  Price/Earnings  \
# 0    MMM           3M Company             Industrials  222.89           24.31
# 1    AOS      A.O. Smith Corp             Industrials   60.24           27.76
# 2    ABT  Abbott Laboratories             Health Care   56.27           22.51
# 3   ABBV          AbbVie Inc.             Health Care  108.48           19.41
# 4    ACN        Accenture plc  Information Technology  150.51           25.47
#
#    Dividend Yield  Earnings/Share  52 Week Low  52 Week High    Market Cap  \
# 0        2.332862            7.92       259.77       175.490  1.387211e+11
# 1        1.147959            1.70        68.39        48.925  1.078342e+10
# 2        1.908982            0.26        64.60        42.280  1.021210e+11
# 3        2.499560            3.29       125.86        60.050  1.813863e+11
# 4        1.714470            5.44       162.60       114.820  9.876586e+10
#
#          EBITDA  Price/Sales  Price/Book  \
# 0  9.048000e+09     4.390271       11.34
# 1  6.010000e+08     3.575483        6.35
# 2  5.744000e+09     3.740480        3.19
# 3  1.031000e+10     6.291571       26.14
# 4  5.643228e+09     2.604117       10.62
#
#                                          SEC Filings
# 0  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 2  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 4  http://www.sec.gov/cgi-bin/browse-edgar?action...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          505 non-null    object
#  1   Name            505 non-null    object
#  2   Sector          505 non-null    object
#  3   Price           505 non-null    float64
#  4   Price/Earnings  503 non-null    float64
#  5   Dividend Yield  505 non-null    float64
#  6   Earnings/Share  505 non-null    float64
#  7   52 Week Low     505 non-null    float64
#  8   52 Week High    505 non-null    float64
#  9   Market Cap      505 non-null    float64
#  10  EBITDA          505 non-null    float64
#  11  Price/Sales     505 non-null    float64
#  12  Price/Book      497 non-null    float64
#  13  SEC Filings     505 non-null    object
# dtypes: float64(10), object(4)
# memory usage: 55.4+ KB

# %% [markdown]
# **Preprocesamiento y Análisis exploratorio**

# %%
#Detección de valores nulos
filas_con_nulos = df[df.isnull().any(axis=1)]
filas_con_nulos.head(20)
# Out:
#     Symbol                  Name                  Sector   Price  \
# 55    ARNC           Arconic Inc             Industrials   24.45
# 199     FL       Foot Locker Inc  Consumer Discretionary   45.88
# 225    HCA          HCA Holdings             Health Care   95.97
# 292    MRO    Marathon Oil Corp.                  Energy   15.68
# 346    OXY  Occidental Petroleum                  Energy   68.47
# 358    PEP          PepsiCo Inc.        Consumer Staples  110.15
# 360   PRGO               Perrigo             Health Care   84.44
# 430    TPR        Tapestry, Inc.  Consumer Discretionary   48.85
# 450    TDG       TransDigm Group             Industrials  283.00
# 460    UNP         Union Pacific             Industrials  124.86
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 55            20.21        0.956175           -0.21        31.17
# 199            9.50        2.582795            4.91        77.86
# 225           14.07        1.422764            5.94       106.84
# 292          -32.00        1.224740           -2.65        19.52
# 346          195.63        4.408186           -0.75        78.09
# 358           21.51        2.837004            4.36       122.51
# 360             NaN        0.731261          -28.01        95.93
# 430             NaN        0.000000            2.09        50.71
# 450           23.76        0.000000            7.92       321.38
# 460           22.06        2.062655           13.52       143.05
#
#      52 Week High    Market Cap        EBITDA  Price/Sales  Price/Book  \
# 55         21.755  1.212330e+10  1.517000e+09     0.942148         NaN
# 199        28.420  5.819080e+09  9.570000e+08     1.036295         NaN
# 225        71.180  3.444905e+10  8.202000e+09     0.725192         NaN
# 292        10.550  1.387501e+10  2.266000e+09     4.657876         NaN
# 346        57.200  5.346769e+10  5.205000e+09     6.044895         NaN
# 358       104.770  1.614133e+11  1.284300e+10     3.670506         NaN
# 360        63.680  1.232638e+10  0.000000e+00     3.385007        2.03
# 430        36.690  1.424720e+10  0.000000e+00     4.078549        4.35
# 450       203.720  1.524120e+10  1.635916e+09     4.268832         NaN
# 460       101.060  1.015133e+11  1.016900e+10     4.860507         NaN
#
#                                            SEC Filings
# 55   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 199  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 225  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 292  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 346  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 358  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 360  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 430  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 450  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 460  http://www.sec.gov/cgi-bin/browse-edgar?action...

# %%
#Tratamiento de valores nulos
#Imputación por sector
df['Price/Book'] = df.groupby('Sector')['Price/Book'].transform(lambda x: x.fillna(x.median()))
df['Price/Earnings'] = df.groupby('Sector')['Price/Earnings'].transform(lambda x: x.fillna(x.median()))

# %%
#Detecciónd e valores atípicos
def valores_atipicos(df, col, inferior, superior):
  Q1 = df[col].quantile(0.25)
  Q3 = df[col].quantile(0.75)
  IQR = Q3 - Q1

  limite_inferior = Q1 - inferior * IQR
  limite_superior = Q3 + superior * IQR

  outliers = df[(df[col] < limite_inferior) | (df[col] > limite_superior)]

  total_validos = df[col].notnull().sum()
  porcentaje = (len(outliers) / total_validos * 100) if total_validos > 0 else 0

  return len(outliers), limite_inferior, limite_superior, porcentaje

lista_resumen = []

columnas_num = df.select_dtypes(include=['number']).columns
for col in columnas_num:
  outliers, limite_inferior, limite_superior, porcentaje = valores_atipicos(df, col, 1.5, 1.5)
  lista_resumen.append([col, outliers, porcentaje, limite_inferior, limite_superior])

lista_resumen = pd.DataFrame(lista_resumen, columns=['Columna', 'Outliers', 'Porcentaje', 'Limite Inferior', 'Limite Superior'])
lista_resumen
# Out:
#           Columna  Outliers  Porcentaje  Limite Inferior  Limite Superior
# 0           Price        33    6.534653    -5.918500e+01     2.219750e+02
# 1  Price/Earnings        47    9.306931    -2.350000e-01     4.132500e+01
# 2  Dividend Yield         9    1.782178    -2.184586e+00     5.760534e+00
# 3  Earnings/Share        41    8.118812    -3.985000e+00     1.061500e+01
# 4     52 Week Low        33    6.534653    -6.957000e+01     2.659500e+02
# 5    52 Week High        28    5.544554    -4.891500e+01     1.840050e+02
# 6      Market Cap        60   11.881188    -3.584935e+10     9.370110e+10
# 7          EBITDA        50    9.900990    -3.604294e+09     8.070974e+09
# 8     Price/Sales        43    8.514851    -2.982038e+00     9.315370e+00
# 9      Price/Book        47    9.306931    -3.960000e+00     1.204000e+01

# %%
# Filtrado de las columnas con datos numéricos
#columnas_num = df.select_dtypes(include=['number']).columns
num_columnas = len(columnas_num)

# Cuadrícula con 3 gráficos por fila
filas = math.ceil(num_columnas / 3)
fig, axes = plt.subplots(filas, 3, figsize=(18, filas * 4))
axes = axes.flatten()

for i, col in enumerate(columnas_num):
    sns.boxplot(x=df[col], ax=axes[i], color='skyblue', flierprops={'markerfacecolor':'red', 'markeredgecolor':'red'})
    axes[i].set_title(f'Distribución de {col}', fontsize=12, fontweight='bold')
    axes[i].set_xlabel('')  # Quitamos el label inferior
    axes[i].grid(axis='x', linestyle='--', alpha=1)

plt.tight_layout()
plt.show()

# %%
df.describe()
# Out:
#              Price  Price/Earnings  Dividend Yield  Earnings/Share  \
# count   505.000000      505.000000      505.000000      505.000000
# mean    103.830634       24.786762        1.895953        3.753743
# std     134.427636       41.160620        1.537214        5.689036
# min       2.820000     -251.530000        0.000000      -28.010000
# 25%      46.250000       15.350000        0.794834        1.490000
# 50%      73.920000       19.450000        1.769255        2.890000
# 75%     116.540000       25.740000        2.781114        5.140000
# max    1806.060000      520.150000       12.661196       44.090000
#
#        52 Week Low  52 Week High    Market Cap        EBITDA  Price/Sales  \
# count   505.000000    505.000000  5.050000e+02  5.050000e+02   505.000000
# mean    122.623832     83.536616  4.923944e+10  3.590328e+09     3.941705
# std     155.362140    105.725473  9.005017e+10  6.840544e+09     3.460110
# min       6.590000      2.800000  2.626102e+09 -5.067000e+09     0.153186
# 25%      56.250000     38.430000  1.273207e+10  7.739320e+08     1.629490
# 50%      86.680000     62.850000  2.140095e+10  1.614399e+09     2.896440
# 75%     140.130000     96.660000  4.511968e+10  3.692749e+09     4.703842
# max    2067.990000   1589.000000  8.095080e+11  7.938600e+10    20.094294
#
#         Price/Book
# count   505.000000
# mean     14.287307
# std      88.955835
# min       0.510000
# 25%       2.040000
# 50%       3.460000
# 75%       6.040000
# max    1403.380000

# %%
#Histogramas de variables cuantitativas
# Filtrado de las columnas con datos numéricos
#columnas_num = df.select_dtypes(include=['number']).columns
#num_columnas = len(columnas_num)

# Cuadrícula con 3 gráficos por fila
filas = math.ceil(num_columnas / 2)
fig, axes = plt.subplots(filas, 2, figsize=(18, filas * 4))
axes = axes.flatten()

for i, col in enumerate(columnas_num):
    sns.histplot(df[col], ax=axes[i], kde=True, color='skyblue')
    axes[i].set_title(f'Distribución de {col}', fontsize=12, fontweight='bold')
    axes[i].set_xlabel(col)
    axes[i].grid(axis='x', linestyle='--', alpha=1)


plt.tight_layout()
plt.show()

# %%
#Normalización de valores
#RobustScaler para evitar la distorsión de los outliers durante la normalización
scaler = RobustScaler()
variables_financieras = ['Price', 'Price/Earnings', 'Dividend Yield', 'Earnings/Share', 'Market Cap', 'EBITDA', 'Price/Sales', 'Price/Book']
valores_escalados = scaler.fit_transform(df[variables_financieras])
df_escalado = pd.DataFrame(valores_escalados, columns=variables_financieras, index=df.index)

# %%
# Distribuciones por sector
#'Price', 'Price/Earnings', 'Dividend Yield', 'Earnings/Share', 'Market Cap', 'EBITDA', 'Price/Sales', 'Price/Book'

# %%
fig = px.box(df, x="Price", y="Sector", color="Sector",
             title="Análisis Interactivo de P/E por Sector",
             hover_data=["Symbol"], points="outliers")
# "Name"

fig.update_layout(showlegend=False, margin=dict(l=150, r=20, t=50, b=50))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3153ed5b-52a5-4f8e-b628-6920c34c356f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3153ed5b-52a5-4f8e-b628-6920c34c356f")) {                    Plotly.newPlot(                        "3153ed5b-52a5-4f8e-b628-6920c34c356f",                        [{"alignmentgroup":"True","boxpoints":"outliers","customdata":[["MMM"],["AOS"],["AYI"],["ALK"],["ALLE"],["AAL"],["AME"],["ARNC"],["BA"],["CHRW"],["CAT"],["CTAS"],["CSX"],["CMI"],["DE"],["DAL"],["DOV"],["ETN"],["EMR"],["EFX"],["EXPD"],["FAST"],["FDX"],["FLS"],["FLR"],["FTV"],["FBHS"],["GD"],["GE"],["GWW"],["HON"],["HII"],["INFO"],["ITW"],["IR"],["JBHT"],["JEC"],["JCI"],["KSU"],["LLL"],["LMT"],["MAS"],["NLSN"],["NSC"],["NOC"],["PCAR"],["PH"],["PNR"],["PWR"],["RTN"],["RSG"],["RHI"],["ROK"],["COL"],["ROP"],["LUV"],["SRCL"],["TXT"],["TDG"],["UNP"],["UAL"],["UPS"],["URI"],["UTX"],["VRSK"],["WM"],["XYL"]],"hovertemplate":"Sector=%{y}\u003cbr\u003ePrice=%{x}\u003cbr\u003eSymbol=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industrials","marker":{"color":"#636efa"},"name":"Industrials","notched":false,"offsetgroup":"Industrials","orientation":"h","showlegend":true,"x":[222.89,60.24,145.41,64.04,77.32,48.6,72.05,24.45,329.66,90.47,145.99,149.32,50.47,165.73,153.66,51.23,96.2,79.41,66.4,114.0,60.36,52.15,239.27,40.82,55.31,69.14,62.44,206.05,14.45,258.6,146.02,225.37,43.73,156.15,87.6,114.81,62.82,36.55,103.53,198.79,334.3,40.7,33.9,136.89,324.01,66.98,174.51,66.67,33.51,198.74,62.72,52.26,178.73,133.31,259.4,55.63,70.55,55.54,283.0,124.86,63.37,109.28,161.99,127.48,92.28,79.12,70.24],"x0":" ","xaxis":"x","y":["Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"outliers","customdata":[["ABT"],["ABBV"],["AET"],["A"],["ALXN"],["ALGN"],["AGN"],["ABC"],["AMGN"],["ANTM"],["BAX"],["BDX"],["BIIB"],["BSX"],["BMY"],["CAH"],["CELG"],["CNC"],["CERN"],["CI"],["DHR"],["DVA"],["XRAY"],["EW"],["EVHC"],["ESRX"],["GILD"],["HCA"],["HSIC"],["HOLX"],["HUM"],["IDXX"],["ILMN"],["INCY"],["ISRG"],["IQV"],["JNJ"],["LH"],["LLY"],["MCK"],["MDT"],["MRK"],["MTD"],["MYL"],["PDCO"],["PKI"],["PRGO"],["PFE"],["DGX"],["REGN"],["RMD"],["SYK"],["COO"],["TMO"],["UNH"],["UHS"],["VAR"],["VRTX"],["WAT"],["ZBH"],["ZTS"]],"hovertemplate":"Sector=%{y}\u003cbr\u003ePrice=%{x}\u003cbr\u003eSymbol=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Health Care","marker":{"color":"#EF553B"},"name":"Health Care","notched":false,"offsetgroup":"Health Care","orientation":"h","showlegend":true,"x":[56.27,108.48,178.0,65.05,108.47,220.71,164.2,91.55,173.12,230.57,62.56,211.44,311.79,25.2,62.69,66.63,91.02,100.36,61.22,189.27,92.16,71.91,56.85,123.78,35.34,73.35,78.22,95.97,70.85,38.8,262.37,169.28,209.54,83.92,381.87,95.23,126.36,165.46,74.21,150.2 ...

# %%
fig = px.box(df, x="Price/Earnings", y="Sector", color="Sector",
             title="Análisis Interactivo de P/E por Sector",
             hover_data=["Symbol"], points="outliers")
# "Name"

fig.update_layout(showlegend=False, margin=dict(l=150, r=20, t=50, b=50))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dc5fc398-8fd1-4580-9314-69c55009a9b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc5fc398-8fd1-4580-9314-69c55009a9b2")) {                    Plotly.newPlot(                        "dc5fc398-8fd1-4580-9314-69c55009a9b2",                        [{"alignmentgroup":"True","boxpoints":"outliers","customdata":[["MMM"],["AOS"],["AYI"],["ALK"],["ALLE"],["AAL"],["AME"],["ARNC"],["BA"],["CHRW"],["CAT"],["CTAS"],["CSX"],["CMI"],["DE"],["DAL"],["DOV"],["ETN"],["EMR"],["EFX"],["EXPD"],["FAST"],["FDX"],["FLS"],["FLR"],["FTV"],["FBHS"],["GD"],["GE"],["GWW"],["HON"],["HII"],["INFO"],["ITW"],["IR"],["JBHT"],["JEC"],["JCI"],["KSU"],["LLL"],["LMT"],["MAS"],["NLSN"],["NSC"],["NOC"],["PCAR"],["PH"],["PNR"],["PWR"],["RTN"],["RSG"],["RHI"],["ROK"],["COL"],["ROP"],["LUV"],["SRCL"],["TXT"],["TDG"],["UNP"],["UAL"],["UPS"],["URI"],["UTX"],["VRSK"],["WM"],["XYL"]],"hovertemplate":"Sector=%{y}\u003cbr\u003ePrice\u002fEarnings=%{x}\u003cbr\u003eSymbol=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industrials","marker":{"color":"#636efa"},"name":"Industrials","notched":false,"offsetgroup":"Industrials","orientation":"h","showlegend":true,"x":[24.31,27.76,18.22,9.66,21.07,9.92,27.61,20.21,27.29,26.0,21.22,32.75,21.94,16.83,23.14,10.37,23.87,17.08,25.74,19.03,25.26,27.02,19.45,26.17,19.9,25.05,20.27,20.71,13.76,22.57,20.68,18.75,26.19,23.62,19.38,30.62,19.45,14.0,19.8,23.14,24.28,22.12,18.73,20.65,24.4,15.72,21.6,18.89,17.54,25.78,26.13,20.18,26.48,22.29,27.57,15.89,16.26,22.13,23.76,22.06,8.85,18.27,16.33,19.26,28.84,25.36,30.94],"x0":" ","xaxis":"x","y":["Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"outliers","customdata":[["ABT"],["ABBV"],["AET"],["A"],["ALXN"],["ALGN"],["AGN"],["ABC"],["AMGN"],["ANTM"],["BAX"],["BDX"],["BIIB"],["BSX"],["BMY"],["CAH"],["CELG"],["CNC"],["CERN"],["CI"],["DHR"],["DVA"],["XRAY"],["EW"],["EVHC"],["ESRX"],["GILD"],["HCA"],["HSIC"],["HOLX"],["HUM"],["IDXX"],["ILMN"],["INCY"],["ISRG"],["IQV"],["JNJ"],["LH"],["LLY"],["MCK"],["MDT"],["MRK"],["MTD"],["MYL"],["PDCO"],["PKI"],["PRGO"],["PFE"],["DGX"],["REGN"],["RMD"],["SYK"],["COO"],["TMO"],["UNH"],["UHS"],["VAR"],["VRTX"],["WAT"],["ZBH"],["ZTS"]],"hovertemplate":"Sector=%{y}\u003cbr\u003ePrice\u002fEarnings=%{x}\u003cbr\u003eSymbol=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Health Care","marker":{"color":"#EF553B"},"name":"Health Care","notched":false,"offsetgroup":"Health Care","orientation":"h","showlegend":true,"x":[22.51,19.41,18.11,27.45,22.18,56.59,10.65,15.54,13.76,19.23,25.12,22.28,14.3,20.0,20.83,12.29,13.27,19.12,27.09,18.11,22.87,20.55,22.65,32.57,10.91,10.72,8.16,14.07,19.85,19.21,22.39,53.57,52.25,-119.89,48.58,21.74,17.31,17.79,17.34,11.68,17.04,13.75,35 ...

# %%
fig = px.box(df, x="Dividend Yield", y="Sector", color="Sector",
             title="Análisis Interactivo de P/E por Sector",
             hover_data=["Symbol"], points="outliers")
# "Name"

fig.update_layout(showlegend=False, margin=dict(l=150, r=20, t=50, b=50))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6fd4b914-62ee-4ba1-b1c6-0153490d7556" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fd4b914-62ee-4ba1-b1c6-0153490d7556")) {                    Plotly.newPlot(                        "6fd4b914-62ee-4ba1-b1c6-0153490d7556",                        [{"alignmentgroup":"True","boxpoints":"outliers","customdata":[["MMM"],["AOS"],["AYI"],["ALK"],["ALLE"],["AAL"],["AME"],["ARNC"],["BA"],["CHRW"],["CAT"],["CTAS"],["CSX"],["CMI"],["DE"],["DAL"],["DOV"],["ETN"],["EMR"],["EFX"],["EXPD"],["FAST"],["FDX"],["FLS"],["FLR"],["FTV"],["FBHS"],["GD"],["GE"],["GWW"],["HON"],["HII"],["INFO"],["ITW"],["IR"],["JBHT"],["JEC"],["JCI"],["KSU"],["LLL"],["LMT"],["MAS"],["NLSN"],["NSC"],["NOC"],["PCAR"],["PH"],["PNR"],["PWR"],["RTN"],["RSG"],["RHI"],["ROK"],["COL"],["ROP"],["LUV"],["SRCL"],["TXT"],["TDG"],["UNP"],["UAL"],["UPS"],["URI"],["UTX"],["VRSK"],["WM"],["XYL"]],"hovertemplate":"Sector=%{y}\u003cbr\u003eDividend Yield=%{x}\u003cbr\u003eSymbol=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industrials","marker":{"color":"#636efa"},"name":"Industrials","notched":false,"offsetgroup":"Industrials","orientation":"h","showlegend":true,"x":[2.3328617,1.1479592,0.35118526,1.9928383,0.8004002,0.7782101,0.75512403,0.9561753,1.9648397,1.987685,2.0215108,1.0344827,1.5102888,2.5008683,1.4866204,2.2655525,1.8815053,2.9404557,2.813225,1.3265306,1.3520038,2.7798648,0.7963368,1.8291216,1.4726508,0.39057052,1.2618296,1.5631542,3.147541,1.9700643,1.9710299,1.2264713,0.0,1.9089574,1.9739007,0.8139042,0.9089532,2.7659574,1.3445379,1.4444605,2.315954,0.98383695,3.6208732,2.018503,1.3030859,1.455816,1.4401833,2.03933,0.0,1.5612764,2.1362228,1.7075773,1.7692552,0.9748892,0.61985797,0.863707,0.0,0.1381454,0.0,2.062655,0.0,2.9666696,0.0,2.1216943,0.0,2.0800195,1.1700794],"x0":" ","xaxis":"x","y":["Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"outliers","customdata":[["ABT"],["ABBV"],["AET"],["A"],["ALXN"],["ALGN"],["AGN"],["ABC"],["AMGN"],["ANTM"],["BAX"],["BDX"],["BIIB"],["BSX"],["BMY"],["CAH"],["CELG"],["CNC"],["CERN"],["CI"],["DHR"],["DVA"],["XRAY"],["EW"],["EVHC"],["ESRX"],["GILD"],["HCA"],["HSIC"],["HOLX"],["HUM"],["IDXX"],["ILMN"],["INCY"],["ISRG"],["IQV"],["JNJ"],["LH"],["LLY"],["MCK"],["MDT"],["MRK"],["MTD"],["MYL"],["PDCO"],["PKI"],["PRGO"],["PFE"],["DGX"],["REGN"],["RMD"],["SYK"],["COO"],["TMO"],["UNH"],["UHS"],["VAR"],["VRTX"],["WAT"],["ZBH"],["ZTS"]],"hovertemplate":"Sector=%{y}\u003cbr\u003eDividend Yield=%{x}\u003cbr\u003eSymbol=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Health Care","marker":{"color":"#EF553B"},"name":"Health Care","notched":false,"offsetgroup":"Health Care","orientation":"h","showlegend":true,"x":[1.9089824,2.4995599,1.101989,0.87 ...

# %%
fig = px.box(df, x="Earnings/Share", y="Sector", color="Sector",
             title="Análisis Interactivo de P/E por Sector",
             hover_data=["Symbol"], points="outliers")
# "Name"

fig.update_layout(showlegend=False, margin=dict(l=150, r=20, t=50, b=50))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ff4ff5c2-ded9-4020-bf89-5c0f719d991e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff4ff5c2-ded9-4020-bf89-5c0f719d991e")) {                    Plotly.newPlot(                        "ff4ff5c2-ded9-4020-bf89-5c0f719d991e",                        [{"alignmentgroup":"True","boxpoints":"outliers","customdata":[["MMM"],["AOS"],["AYI"],["ALK"],["ALLE"],["AAL"],["AME"],["ARNC"],["BA"],["CHRW"],["CAT"],["CTAS"],["CSX"],["CMI"],["DE"],["DAL"],["DOV"],["ETN"],["EMR"],["EFX"],["EXPD"],["FAST"],["FDX"],["FLS"],["FLR"],["FTV"],["FBHS"],["GD"],["GE"],["GWW"],["HON"],["HII"],["INFO"],["ITW"],["IR"],["JBHT"],["JEC"],["JCI"],["KSU"],["LLL"],["LMT"],["MAS"],["NLSN"],["NSC"],["NOC"],["PCAR"],["PH"],["PNR"],["PWR"],["RTN"],["RSG"],["RHI"],["ROK"],["COL"],["ROP"],["LUV"],["SRCL"],["TXT"],["TDG"],["UNP"],["UAL"],["UPS"],["URI"],["UTX"],["VRSK"],["WM"],["XYL"]],"hovertemplate":"Sector=%{y}\u003cbr\u003eEarnings\u002fShare=%{x}\u003cbr\u003eSymbol=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industrials","marker":{"color":"#636efa"},"name":"Industrials","notched":false,"offsetgroup":"Industrials","orientation":"h","showlegend":true,"x":[7.92,1.7,7.43,8.28,2.37,3.91,2.94,-0.21,13.47,3.57,1.26,4.38,6.07,8.23,6.64,4.94,5.15,6.68,2.35,4.04,2.36,2.01,11.07,1.12,1.99,2.46,3.04,9.55,-0.72,10.02,2.08,12.15,1.0,4.86,5.07,6.19,2.43,1.71,9.16,8.51,6.83,1.47,1.39,18.73,11.47,4.75,7.24,3.63,1.28,6.95,1.77,2.32,6.35,4.8,9.38,5.82,2.08,1.14,7.92,13.52,7.05,5.62,15.72,5.7,3.45,2.66,1.83],"x0":" ","xaxis":"x","y":["Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"outliers","customdata":[["ABT"],["ABBV"],["AET"],["A"],["ALXN"],["ALGN"],["AGN"],["ABC"],["AMGN"],["ANTM"],["BAX"],["BDX"],["BIIB"],["BSX"],["BMY"],["CAH"],["CELG"],["CNC"],["CERN"],["CI"],["DHR"],["DVA"],["XRAY"],["EW"],["EVHC"],["ESRX"],["GILD"],["HCA"],["HSIC"],["HOLX"],["HUM"],["IDXX"],["ILMN"],["INCY"],["ISRG"],["IQV"],["JNJ"],["LH"],["LLY"],["MCK"],["MDT"],["MRK"],["MTD"],["MYL"],["PDCO"],["PKI"],["PRGO"],["PFE"],["DGX"],["REGN"],["RMD"],["SYK"],["COO"],["TMO"],["UNH"],["UHS"],["VAR"],["VRTX"],["WAT"],["ZBH"],["ZTS"]],"hovertemplate":"Sector=%{y}\u003cbr\u003eEarnings\u002fShare=%{x}\u003cbr\u003eSymbol=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Health Care","marker":{"color":"#EF553B"},"name":"Health Care","notched":false,"offsetgroup":"Health Care","orientation":"h","showlegend":true,"x":[0.26,3.29,5.75,2.1,1.77,2.84,38.35,1.64,2.57,14.36,1.29,4.65,11.94,0.07,2.65,4.04,3.58,3.23,1.84,7.2,3.53,4.3,1.99,2.88,-0.48,5.39,9.95,5.94,3.1,2.64,4.06,2.94,4.92,0.54,5.67,0.76,0.39,7.02,-0.2,22.74,2.89,1.4,14.24,0.93,1.79,2.64,-28.01,3.51,5.5,7.74,2.41,2.68,7.52,5.6,10.71,7.14,2.69,1.04,0.19,9.01,1.6 ...

# %%
fig = px.box(df, x="Market Cap", y="Sector", color="Sector",
             title="Análisis Interactivo de P/E por Sector",
             hover_data=["Symbol"], points="outliers")
# "Name"

fig.update_layout(showlegend=False, margin=dict(l=150, r=20, t=50, b=50))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1238678b-4b60-42f8-86e0-5de1c5f1f111" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1238678b-4b60-42f8-86e0-5de1c5f1f111")) {                    Plotly.newPlot(                        "1238678b-4b60-42f8-86e0-5de1c5f1f111",                        [{"alignmentgroup":"True","boxpoints":"outliers","customdata":[["MMM"],["AOS"],["AYI"],["ALK"],["ALLE"],["AAL"],["AME"],["ARNC"],["BA"],["CHRW"],["CAT"],["CTAS"],["CSX"],["CMI"],["DE"],["DAL"],["DOV"],["ETN"],["EMR"],["EFX"],["EXPD"],["FAST"],["FDX"],["FLS"],["FLR"],["FTV"],["FBHS"],["GD"],["GE"],["GWW"],["HON"],["HII"],["INFO"],["ITW"],["IR"],["JBHT"],["JEC"],["JCI"],["KSU"],["LLL"],["LMT"],["MAS"],["NLSN"],["NSC"],["NOC"],["PCAR"],["PH"],["PNR"],["PWR"],["RTN"],["RSG"],["RHI"],["ROK"],["COL"],["ROP"],["LUV"],["SRCL"],["TXT"],["TDG"],["UNP"],["UAL"],["UPS"],["URI"],["UTX"],["VRSK"],["WM"],["XYL"]],"hovertemplate":"Sector=%{y}\u003cbr\u003eMarket Cap=%{x}\u003cbr\u003eSymbol=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industrials","marker":{"color":"#636efa"},"name":"Industrials","notched":false,"offsetgroup":"Industrials","orientation":"h","showlegend":true,"x":[138721055226.0,10783419933.0,6242377704.0,7903173734.0,7599609494.0,24594852352.0,17139651923.0,12123300000.0,205617405233.0,12932483889.0,91822049046.0,16676145923.0,47340511707.0,28669230787.0,52186628646.0,38393603535.0,15566645713.0,35961772000.0,44040298425.0,14121334618.0,11040678071.0,15311373377.0,67280478816.0,5427884956.0,7978485059.0,24916503061.0,9624169008.0,64180390701.0,132249296250.0,14639308205.0,114422168609.0,10628247899.0,17969275816.0,55994378108.0,22785450609.0,12945366350.0,9326484316.0,34822224800.0,11037040988.0,16229343134.0,98102120000.0,13428792315.0,13377670080.0,40543547441.0,58782413951.0,24152102921.0,24421668509.0,12466660892.0,5330131216.0,59066255840.0,21590903863.0,7047165475.0,24123216432.0,22197870556.0,27247789759.0,34351211637.0,6218560288.0,15254672353.0,15241203731.0,101513290382.0,19363059152.0,96436356833.0,14654954091.0,105387272474.0,15594677147.0,35488486675.0,12915021000.0],"x0":" ","xaxis":"x","y":["Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"outliers","customdata":[["ABT"],["ABBV"],["AET"],["A"],["ALXN"],["ALGN"],["AGN"],["ABC"],["AMGN"],["ANTM"],["BAX"],["BDX"],["BIIB"],["BSX"],["BMY"],["CAH"],["CELG"],["CNC"],["CERN"],["CI"],["DHR"],["DVA"],["XRAY"],["EW"],["EVHC"],["ESRX"],["GILD"],["HCA"],["HSIC"],["HOLX"],["HUM"],["IDXX"],["ILMN"],["INCY"],["ISRG"],["IQV"],["JNJ"],["LH"],["LLY"],["MCK"],["MDT"],["MRK"],["MTD"],["MYL"],["PDCO"],["PKI"],["PRGO"],["PFE"],["DGX"],["REGN"],["RMD"],["SYK"],["COO"],["TMO"],["UNH"],["UHS"],["VAR"],["VRTX"],["WAT"],["ZBH"],["ZTS"]],"hovertemplate":"Sector=%{y}\ ...

# %%
fig = px.box(df, x="EBITDA", y="Sector", color="Sector",
             title="Análisis Interactivo de P/E por Sector",
             hover_data=["Symbol"], points="outliers")
# "Name"

fig.update_layout(showlegend=False, margin=dict(l=150, r=20, t=50, b=50))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f41dbfd4-bd15-40ec-9837-2b6b76b67c54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f41dbfd4-bd15-40ec-9837-2b6b76b67c54")) {                    Plotly.newPlot(                        "f41dbfd4-bd15-40ec-9837-2b6b76b67c54",                        [{"alignmentgroup":"True","boxpoints":"outliers","customdata":[["MMM"],["AOS"],["AYI"],["ALK"],["ALLE"],["AAL"],["AME"],["ARNC"],["BA"],["CHRW"],["CAT"],["CTAS"],["CSX"],["CMI"],["DE"],["DAL"],["DOV"],["ETN"],["EMR"],["EFX"],["EXPD"],["FAST"],["FDX"],["FLS"],["FLR"],["FTV"],["FBHS"],["GD"],["GE"],["GWW"],["HON"],["HII"],["INFO"],["ITW"],["IR"],["JBHT"],["JEC"],["JCI"],["KSU"],["LLL"],["LMT"],["MAS"],["NLSN"],["NSC"],["NOC"],["PCAR"],["PH"],["PNR"],["PWR"],["RTN"],["RSG"],["RHI"],["ROK"],["COL"],["ROP"],["LUV"],["SRCL"],["TXT"],["TDG"],["UNP"],["UAL"],["UPS"],["URI"],["UTX"],["VRSK"],["WM"],["XYL"]],"hovertemplate":"Sector=%{y}\u003cbr\u003eEBITDA=%{x}\u003cbr\u003eSymbol=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industrials","marker":{"color":"#636efa"},"name":"Industrials","notched":false,"offsetgroup":"Industrials","orientation":"h","showlegend":true,"x":[9048000000.0,601000000.0,587800000.0,1665000000.0,531800000.0,5761000000.0,1025763000.0,1517000000.0,12476000000.0,868096000.0,8136000000.0,1097295000.0,5003000000.0,2924000000.0,4053300000.0,8348000000.0,1513291000.0,4253000000.0,2542000000.0,1141200000.0,721643000.0,1009600000.0,8062000000.0,463066000.0,709756000.0,1508300000.0,814500000.0,4618000000.0,-206000000.0,1279846000.0,8333000000.0,1107000000.0,1018900000.0,3924000000.0,1987100000.0,1007309000.0,409832000.0,4295000000.0,1295400000.0,1137000000.0,7115000000.0,1179000000.0,1836000000.0,4737000000.0,3884000000.0,3619200000.0,2092089000.0,863700000.0,649404000.0,3868000000.0,2734000000.0,565196000.0,1323200000.0,1696000000.0,1555209000.0,4533000000.0,305085000.0,1454000000.0,1635916000.0,10169000000.0,5929000000.0,7919000000.0,2760000000.0,10584000000.0,1011200000.0,3896000000.0,722000000.0],"x0":" ","xaxis":"x","y":["Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"outliers","customdata":[["ABT"],["ABBV"],["AET"],["A"],["ALXN"],["ALGN"],["AGN"],["ABC"],["AMGN"],["ANTM"],["BAX"],["BDX"],["BIIB"],["BSX"],["BMY"],["CAH"],["CELG"],["CNC"],["CERN"],["CI"],["DHR"],["DVA"],["XRAY"],["EW"],["EVHC"],["ESRX"],["GILD"],["HCA"],["HSIC"],["HOLX"],["HUM"],["IDXX"],["ILMN"],["INCY"],["ISRG"],["IQV"],["JNJ"],["LH"],["LLY"],["MCK"],["MDT"],["MRK"],["MTD"],["MYL"],["PDCO"],["PKI"],["PRGO"],["PFE"],["DGX"],["REGN"],["RMD"],["SYK"],["COO"],["TMO"],["UNH"],["UHS"],["VAR"],["VRTX"],["WAT"],["ZBH"],["ZTS"]],"hovertemplate":"Sector=%{y}\u003cbr\u003eEBITDA=%{x}\u003cbr\u003eSymbol=%{customdata[0]}\u003cextra\u003e ...

# %%
fig = px.box(df, x="Price/Sales", y="Sector", color="Sector",
             title="Análisis Interactivo de P/E por Sector",
             hover_data=["Symbol"], points="outliers")
# "Name"

fig.update_layout(showlegend=False, margin=dict(l=150, r=20, t=50, b=50))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8e01336e-2756-443e-9c68-ca12974b3bc7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e01336e-2756-443e-9c68-ca12974b3bc7")) {                    Plotly.newPlot(                        "8e01336e-2756-443e-9c68-ca12974b3bc7",                        [{"alignmentgroup":"True","boxpoints":"outliers","customdata":[["MMM"],["AOS"],["AYI"],["ALK"],["ALLE"],["AAL"],["AME"],["ARNC"],["BA"],["CHRW"],["CAT"],["CTAS"],["CSX"],["CMI"],["DE"],["DAL"],["DOV"],["ETN"],["EMR"],["EFX"],["EXPD"],["FAST"],["FDX"],["FLS"],["FLR"],["FTV"],["FBHS"],["GD"],["GE"],["GWW"],["HON"],["HII"],["INFO"],["ITW"],["IR"],["JBHT"],["JEC"],["JCI"],["KSU"],["LLL"],["LMT"],["MAS"],["NLSN"],["NSC"],["NOC"],["PCAR"],["PH"],["PNR"],["PWR"],["RTN"],["RSG"],["RHI"],["ROK"],["COL"],["ROP"],["LUV"],["SRCL"],["TXT"],["TDG"],["UNP"],["UAL"],["UPS"],["URI"],["UTX"],["VRSK"],["WM"],["XYL"]],"hovertemplate":"Sector=%{y}\u003cbr\u003ePrice\u002fSales=%{x}\u003cbr\u003eSymbol=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industrials","marker":{"color":"#636efa"},"name":"Industrials","notched":false,"offsetgroup":"Industrials","orientation":"h","showlegend":true,"x":[4.3902707,3.5754826,1.7953473,0.9801092,4.265232,0.58022565,4.015368,0.94214815,2.1560605,0.85282737,2.0468428,2.7614057,4.216355,1.9406168,2.3746448,0.91792434,1.986176,1.8161736,3.6707752,5.6338058,2.190319,3.472977,1.0751684,2.0803037,0.5516402,5.1682673,1.8434572,2.0481362,1.0887611,1.3995146,2.8267899,1.8924941,5.0604,3.9286149,1.6147361,1.7697402,1.2129636,1.1415336,4.281897,1.4884604,1.8781451,2.308266,2.7288198,3.8525908,2.209576,1.28693,1.8652664,2.5191512,0.77893436,2.2938328,2.8841186,1.3330402,3.760594,3.781273,5.9715905,1.6294897,2.2607324,1.0645695,4.268832,4.8605075,0.5020496,1.4744618,2.1782618,1.7324123,9.935474,3.2787669,2.7262094],"x0":" ","xaxis":"x","y":["Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"outliers","customdata":[["ABT"],["ABBV"],["AET"],["A"],["ALXN"],["ALGN"],["AGN"],["ABC"],["AMGN"],["ANTM"],["BAX"],["BDX"],["BIIB"],["BSX"],["BMY"],["CAH"],["CELG"],["CNC"],["CERN"],["CI"],["DHR"],["DVA"],["XRAY"],["EW"],["EVHC"],["ESRX"],["GILD"],["HCA"],["HSIC"],["HOLX"],["HUM"],["IDXX"],["ILMN"],["INCY"],["ISRG"],["IQV"],["JNJ"],["LH"],["LLY"],["MCK"],["MDT"],["MRK"],["MTD"],["MYL"],["PDCO"],["PKI"],["PRGO"],["PFE"],["DGX"],["REGN"],["RMD"],["SYK"],["COO"],["TMO"],["UNH"],["UHS"],["VAR"],["VRTX"],["WAT"],["ZBH"],["ZTS"]],"hovertemplate":"Sector=%{y}\u003cbr\u003ePrice\u002fSales=%{x}\u003cbr\u003eSymbol=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Health Care","marker":{"color":"#EF553B"},"name":"Health Care","notched":false,"offsetgroup":"Health Care","orientation":"h","showlegend":true, ...

# %%
fig = px.box(df, x="Price/Book", y="Sector", color="Sector",
             title="Análisis Interactivo de P/E por Sector",
             hover_data=["Symbol"], points="outliers")
# "Name"

fig.update_layout(showlegend=False, margin=dict(l=150, r=20, t=50, b=50))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="78f4ab7d-d3a3-4cd0-8d34-0b9bc53a74cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78f4ab7d-d3a3-4cd0-8d34-0b9bc53a74cc")) {                    Plotly.newPlot(                        "78f4ab7d-d3a3-4cd0-8d34-0b9bc53a74cc",                        [{"alignmentgroup":"True","boxpoints":"outliers","customdata":[["MMM"],["AOS"],["AYI"],["ALK"],["ALLE"],["AAL"],["AME"],["ARNC"],["BA"],["CHRW"],["CAT"],["CTAS"],["CSX"],["CMI"],["DE"],["DAL"],["DOV"],["ETN"],["EMR"],["EFX"],["EXPD"],["FAST"],["FDX"],["FLS"],["FLR"],["FTV"],["FBHS"],["GD"],["GE"],["GWW"],["HON"],["HII"],["INFO"],["ITW"],["IR"],["JBHT"],["JEC"],["JCI"],["KSU"],["LLL"],["LMT"],["MAS"],["NLSN"],["NSC"],["NOC"],["PCAR"],["PH"],["PNR"],["PWR"],["RTN"],["RSG"],["RHI"],["ROK"],["COL"],["ROP"],["LUV"],["SRCL"],["TXT"],["TDG"],["UNP"],["UAL"],["UPS"],["URI"],["UTX"],["VRSK"],["WM"],["XYL"]],"hovertemplate":"Sector=%{y}\u003cbr\u003ePrice\u002fBook=%{x}\u003cbr\u003eSymbol=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industrials","marker":{"color":"#636efa"},"name":"Industrials","notched":false,"offsetgroup":"Industrials","orientation":"h","showlegend":true,"x":[11.34,6.35,3.55,2.21,20.48,6.03,4.54,4.46,182.86,9.31,5.75,6.53,4.27,3.89,5.31,2.67,3.59,2.17,5.01,4.59,5.55,7.39,3.9,3.15,2.4,7.17,3.76,5.45,1.7,8.1,5.71,6.04,2.24,10.99,3.34,8.55,2.01,1.69,2.39,3.12,45.55,11.93,3.02,3.09,7.96,3.07,4.39,2.48,1.43,5.28,2.83,5.98,10.94,3.46,4.23,3.84,2.15,2.57,4.46,4.46,2.09,64.7,4.53,3.4,9.34,6.73,5.31],"x0":" ","xaxis":"x","y":["Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"outliers","customdata":[["ABT"],["ABBV"],["AET"],["A"],["ALXN"],["ALGN"],["AGN"],["ABC"],["AMGN"],["ANTM"],["BAX"],["BDX"],["BIIB"],["BSX"],["BMY"],["CAH"],["CELG"],["CNC"],["CERN"],["CI"],["DHR"],["DVA"],["XRAY"],["EW"],["EVHC"],["ESRX"],["GILD"],["HCA"],["HSIC"],["HOLX"],["HUM"],["IDXX"],["ILMN"],["INCY"],["ISRG"],["IQV"],["JNJ"],["LH"],["LLY"],["MCK"],["MDT"],["MRK"],["MTD"],["MYL"],["PDCO"],["PKI"],["PRGO"],["PFE"],["DGX"],["REGN"],["RMD"],["SYK"],["COO"],["TMO"],["UNH"],["UHS"],["VAR"],["VRTX"],["WAT"],["ZBH"],["ZTS"]],"hovertemplate":"Sector=%{y}\u003cbr\u003ePrice\u002fBook=%{x}\u003cbr\u003eSymbol=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Health Care","marker":{"color":"#EF553B"},"name":"Health Care","notched":false,"offsetgroup":"Health Care","orientation":"h","showlegend":true,"x":[3.19,26.14,3.79,4.56,2.82,16.44,0.83,9.73,3.91,2.28,3.77,3.98,5.51,4.78,6.75,3.03,7.49,2.58,4.62,3.39,2.65,2.79,1.8,8.48,0.64,2.65,4.12,3.85,3.74,4.0,3.33,196.21,10.89,10.25,9.48,2.77,4.74,2.71,5.73,2.68,2.14,4.02,31.69,1.63,2.34,3.25,2.03,3.4,2.82,5.89,6.61,5.54,3.57,3.38,4.71,2.21,7.32,21.91,6.15,2.39,18.09],"x0" ...

# %%
df_corr = df.copy()
df_corr.drop(columns=['Symbol', 'Name', 'Sector', 'SEC Filings'], inplace=True)

fig, axs = plt.subplots(ncols=3, nrows=1, figsize=(18, 6))

sns.heatmap(df_corr.corr(), ax=axs[0], annot=False, cmap='viridis')
axs[0].set_title('Correlación de Pearson')

sns.heatmap(df_corr.corr(method='spearman'), ax=axs[1], annot=False, cmap='viridis')
axs[1].set_title('Correlación de Spearman')

sns.heatmap(df_corr.corr(method='kendall'), ax=axs[2], annot=False, cmap='viridis')
axs[2].set_title('Correlación de Kendall')

plt.tight_layout()
plt.show()
